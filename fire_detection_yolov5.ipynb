# %%
# !unzip /content/drive/MyDrive/fire.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: fire/train/images/WEBFire1151.jpg
#   inflating: fire/train/images/WEBFire1152.jpg
#   inflating: fire/train/images/WEBFire1155.jpg
#   inflating: fire/train/images/WEBFire1157.jpg
#   inflating: fire/train/images/WEBFire1169.jpg
#   inflating: fire/train/images/WEBFire1171.jpg
#   inflating: fire/train/images/WEBFire1178.jpg
#   inflating: fire/train/images/WEBFire1179.jpg
#   inflating: fire/train/images/WEBFire1180.jpg
#   inflating: fire/train/images/WEBFire1183.jpg
#   inflating: fire/train/images/WEBFire1185.jpg
#   inflating: fire/train/images/WEBFire1186.jpg
#   inflating: fire/train/images/WEBFire1187.jpg
#   inflating: fire/train/images/WEBFire1188.jpg
#   inflating: fire/train/images/WEBFire1189.jpg
#   inflating: fire/train/images/WEBFire1190.jpg
#   inflating: fire/train/images/WEBFire1191.jpg
#   inflating: fire/train/images/WEBFire1194.jpg
#   inflating: fire/train/images/WEBFire1195.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -U -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16283, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 16283 (delta 76), reused 93 (delta 33), pack-reused 16103
# Receiving objects: 100% (16283/16283), 15.10 MiB | 23.40 MiB/s, done.
# Resolving deltas: 100% (11111/11111), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.4/196.4 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 44.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 70.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.5/285.5 kB 37.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.0 MB/s eta 0:00:00
# ...

# %%
# !python /content/yolov5/train.py --img 640 --batch 16 --epochs 3 --data /content/fire_config.yaml --weights yolov5s.pt --workers 1
# Out:
# 2024-01-12 03:59:55.841799: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-12 03:59:55.841853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-12 03:59:55.843301: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !pip install utils
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for utils: filename=utils-1.0.2-py2.py3-none-any.whl size=13905 sha256=acc11dc98ff79ef4aab44407176bcf02b71a6ec14b700d60f44504c16c8399fd
#   Stored in directory: /root/.cache/pip/wheels/b8/39/f5/9d0ca31dba85773ececf0a7f5469f18810e1c8a8ed9da28ca7
# Successfully built utils
# ...

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/datasets/fire/val/images/
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/datasets/fire/val/images/, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-272-gde64179 Python-3.10.12 torch-2.1.2+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/150 /content/datasets/fire/val/images/0.jpg: 480x640 1 fire, 46.6ms
# image 2/150 /content/datasets/fire/val/images/0016f8c09384627e.jpg: 480x640 1 fire, 9.0ms
# image 3/150 /content/datasets/fire/val/images/004dec94c5de631f.jpg: 480x640 1 fire, 8.9ms
# ...

# %%
import torch
import os
import glob
from IPython.display import Image, display

# %%
images = glob.glob('/content/yolov5/runs/detect/exp/*.jpg')

for imageName in images[:3]: #assuming JPG
    display(Image(filename=imageName, width=400))

# %%
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/input.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/input.mp4, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-272-gde64179 Python-3.10.12 torch-2.1.2+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/126) /content/input.mp4: 640x384 (no detections), 50.1ms
# video 1/1 (2/126) /content/input.mp4: 640x384 (no detections), 12.0ms
# video 1/1 (3/126) /content/input.mp4: 640x384 (no detections), 7.5ms
# video 1/1 (4/126) /content/input.mp4: 640x384 (no detections), 7.6ms
# ...

# %%
import moviepy.editor
moviepy.editor.ipython_display("/content/yolov5/runs/detect/exp2/input.mp4")
# Out:
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
